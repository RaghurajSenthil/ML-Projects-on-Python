# %%
! pip install kaggle

# %%
! mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle competitions download google-smartphone-decimeter-challenge
# Out:
# 403 - Forbidden

# %%
! kaggle datasets download arenagrenade/the-complete-pokemon-images-data-set
# Out:
# ...
#  98% 109M/111M [00:00<00:00, 115MB/s]
# 100% 111M/111M [00:00<00:00, 119MB/s]

# %%
! unzip /content/the-complete-pokemon-images-data-set.zip
# Out:
# Archive:  /content/the-complete-pokemon-images-data-set.zip
#   inflating: Pokemon Dataset/abomasnow.png
#   inflating: Pokemon Dataset/abra.png
#   inflating: Pokemon Dataset/absol.png
#   inflating: Pokemon Dataset/accelgor.png
#   inflating: Pokemon Dataset/aegislash-shield.png
#   inflating: Pokemon Dataset/aerodactyl.png
#   inflating: Pokemon Dataset/aggron.png
#   inflating: Pokemon Dataset/aipom.png
#   inflating: Pokemon Dataset/alakazam.png
#   inflating: Pokemon Dataset/alcremie.png
#   inflating: Pokemon Dataset/alomomola.png
#   inflating: Pokemon Dataset/altaria.png
#   inflating: Pokemon Dataset/amaura.png
#   inflating: Pokemon Dataset/ambipom.png
#   inflating: Pokemon Dataset/amoonguss.png
#   inflating: Pokemon Dataset/ampharos.png
#   inflating: Pokemon Dataset/anorith.png
#   inflating: Pokemon Dataset/appletun.png
#   inflating: Pokemon Dataset/applin.png
#   inflating: Pokemon Dataset/araquanid.png
#   inflating: Pokemon Dataset/arbok.png
# ...

# %%
import matplotlib.pyplot as plt

image = plt.imread('/content/Pokemon Dataset/abomasnow.png')
plt.imshow(image)
